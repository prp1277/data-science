# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import requests
import pandas as pd

r = requests.get('https://api.github.com/users/prp1277')
print(r.json())
# Out:
# {'login': 'prp1277', 'id': 36834793, 'node_id': 'MDQ6VXNlcjM2ODM0Nzkz', 'avatar_url': 'https://avatars2.githubusercontent.com/u/36834793?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/prp1277', 'html_url': 'https://github.com/prp1277', 'followers_url': 'https://api.github.com/users/prp1277/followers', 'following_url': 'https://api.github.com/users/prp1277/following{/other_user}', 'gists_url': 'https://api.github.com/users/prp1277/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/prp1277/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/prp1277/subscriptions', 'organizations_url': 'https://api.github.com/users/prp1277/orgs', 'repos_url': 'https://api.github.com/users/prp1277/repos', 'events_url': 'https://api.github.com/users/prp1277/events{/privacy}', 'received_events_url': 'https://api.github.com/users/prp1277/received_events', 'type': 'User', 'site_admin': False, 'name': 'Patrick Powell', 'company': 'Payless Office Products', 'b
# ...

# %%
jsonData = r.json()
print(jsonData)
# Out:
# {'login': 'prp1277', 'id': 36834793, 'node_id': 'MDQ6VXNlcjM2ODM0Nzkz', 'avatar_url': 'https://avatars2.githubusercontent.com/u/36834793?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/prp1277', 'html_url': 'https://github.com/prp1277', 'followers_url': 'https://api.github.com/users/prp1277/followers', 'following_url': 'https://api.github.com/users/prp1277/following{/other_user}', 'gists_url': 'https://api.github.com/users/prp1277/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/prp1277/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/prp1277/subscriptions', 'organizations_url': 'https://api.github.com/users/prp1277/orgs', 'repos_url': 'https://api.github.com/users/prp1277/repos', 'events_url': 'https://api.github.com/users/prp1277/events{/privacy}', 'received_events_url': 'https://api.github.com/users/prp1277/received_events', 'type': 'User', 'site_admin': False, 'name': 'Patrick Powell', 'company': 'Payless Office Products', 'b
# ...

# %%
from pandas.io.json import json_normalize
json_normalize(jsonData)
# Out:
#      login        id               node_id  \
# 0  prp1277  36834793  MDQ6VXNlcjM2ODM0Nzkz
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars2.githubusercontent.com/u/36834...
#
#                                     url                    html_url  \
# 0  https://api.github.com/users/prp1277  https://github.com/prp1277
#
#                                     followers_url  \
# 0  https://api.github.com/users/prp1277/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/prp1277/following...
#
#                                            gists_url  ...   location email  \
# 0  https://api.github.com/users/prp1277/gists{/gi...  ...  Omaha, NE  None
#
#   hireable                                          bio public_repos  \
# 0     True  Came here for finance, learned programming.           20
#
#   public_gists followers  following            created_at  \
# ...

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize

githubURL = 'https://api.github.com/users/prp1277/received_events'

req = requests.get(githubURL)
json_normalize(req.json())
# Out:
#              id              type  public            created_at  actor.id  \
# 0   11473249723        WatchEvent    True  2020-02-09T22:00:35Z  26686700
# 1   11472645172  PullRequestEvent    True  2020-02-09T18:28:50Z  49699333
# 2   11472645143       CreateEvent    True  2020-02-09T18:28:50Z  49699333
# 3   11472645131       CreateEvent    True  2020-02-09T18:28:50Z  49699333
# 4   11472645128  PullRequestEvent    True  2020-02-09T18:28:49Z  49699333
# 5   11472645102  PullRequestEvent    True  2020-02-09T18:28:49Z  49699333
# 6   11472645105       CreateEvent    True  2020-02-09T18:28:49Z  49699333
# 7   11472645065  PullRequestEvent    True  2020-02-09T18:28:48Z  49699333
# 8   11472645039       CreateEvent    True  2020-02-09T18:28:48Z  49699333
# 9   11472576698  PullRequestEvent    True  2020-02-09T18:04:31Z  49699333
# 10  11472576676       CreateEvent    True  2020-02-09T18:04:30Z  49699333
# 11  11471314618         ForkEvent    True  2020-02-09T10:23:06Z  32043762
# ...
